# %%
from roboflow import Roboflow
rf = Roboflow(api_key="7XZbRL26c250G3mkz5aF")
project = rf.workspace("viren-dhanwani").project("tennis-ball-detection")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in tennis-ball-detection-1 to yolov5pytorch:: 100%|██████████| 27320/27320 [00:03<00:00, 9063.31it/s]
# Extracting Dataset Version Zip to tennis-ball-detection-1 in yolov5pytorch:: 100%|██████████| 524/524 [00:00<00:00, 1668.49it/s]

# %%
# !yolo task=detect mode=train model=yolov5l6u data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# ^C
